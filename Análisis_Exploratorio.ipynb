# %%
import pandas as pd

# %%
# Leer el archivo CSV
df = pd.read_csv("master_final.csv", encoding='utf-8')

# %%
# Imprimir cantidad de observaciones y variables
print(f"Número de filas: {len(df)}\nNúmero de columnas: {len(df.columns)}\n")

# Información general del DataFrame
print(df.info())

# Estadísticas descriptivas
print(df.describe())
# Out:
# Número de filas: 39999
# Número de columnas: 32
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39999 entries, 0 to 39998
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   depreg     7989 non-null   float64
#  1   depreg.1   32010 non-null  float64
#  2   mupreg     7989 non-null   float64
#  3   mupreg.1   32010 non-null  float64
#  4   mesreg     7989 non-null   float64
#  5   mesreg.1   32010 non-null  float64
#  6   añoreg     7989 non-null   float64
#  7   añoreg.1   32010 non-null  float64
#  8   diaocu     7989 non-null   float64
#  9   diaocu.1   32010 non-null  float64
#  10  mesocu     7989 non-null   float64
#  11  mesocu.1   32010 non-null  float64
#  12  añoocu     7989 non-null   float64
#  13  añoocu.1   15736 non-null  float64
#  14  depocu     7989 non-null   float64
#  15  depocu.1   32010 non-null  float64
#  16  mupocu     7989 non-null   float64
#  17  mupocu.1   32010 non-null  float64
#  18  edadhom    7989 non-null   float64
#  19  edadhom.1  32010 non-null  float64
#  20  edadmuj    7989 non-null   float64
#  21  edadmuj.1  32010 non-null  float64
#  22  grethom    7989 non-null   float64
#  23  gretmuj    7989 non-null   float64
#  24  nachom     7988 non-null   float64
#  25  nachom.1   32010 non-null  float64
#  26  nacmuj     7988 non-null   float64
#  27  nacmuj.1   32010 non-null  float64
#  28  escohom    7989 non-null   float64
#  29  escomuj    7989 non-null   float64
#  30  ocupahom   7989 non-null   float64
#  31  ocupamuj   7989 non-null   float64
# dtypes: float64(32)
# memory usage: 9.8 MB
# None
#             depreg      depreg.1       mupreg      mupreg.1       mesreg  \
# count  7989.000000  32010.000000  7989.000000  32010.000000  7989.000000
# mean      7.870447      7.476007   791.729628    752.265355     6.653899
# std       7.277590      7.048145   728.342936    705.568406     3.373956
# min       1.000000      1.000000   101.000000    101.000000     1.000000
# 25%       1.000000      1.000000   101.000000    101.000000     4.000000
# 50%       5.000000      5.000000   511.000000    505.000000     7.000000
# 75%      14.000000     13.000000  1406.000000   1301.000000    10.000000
# max      22.000000     22.000000  2217.000000   2217.000000    12.000000
#
#            mesreg.1       añoreg      añoreg.1       diaocu      diaocu.1  \
# count  32010.000000  7989.000000  32010.000000  7989.000000  32010.000000
# mean       6.507060  2010.772437   2014.677882    15.593441     15.741550
# std        3.375252     0.647816      1.711261     8.671648      8.691388
# min        1.000000  2010.000000   2012.000000     1.000000      1.000000
# 25%        4.000000  2010.000000   2013.000000     8.000000      8.000000
# 50%        7.000000  2011.000000   2015.000000    15.000000     16.000000
# 75%        9.000000  2011.000000   2016.000000    23.000000     23.000000
# max       12.000000  2012.000000   2018.000000    31.000000     31.000000
#
#        ...      grethom      gretmuj       nachom      nachom.1       nacmuj  \
# count  ...  7989.000000  7989.000000  7988.000000  32010.000000  7988.000000
# mean   ...     7.515334     7.550632   331.068102    363.806092   329.599399
# std    ...     2.920439     2.890567   290.093652    626.414776   268.946944
# min    ...     1.000000     1.000000    -1.000000     32.000000    -1.000000
# 25%    ...     9.000000     9.000000   320.000000    320.000000   320.000000
# 50%    ...     9.000000     9.000000   320.000000    320.000000   320.000000
# 75%    ...     9.000000     9.000000   320.000000    320.000000   320.000000
# max    ...     9.000000     9.000000  9999.000000   9999.000000  9999.000000
#
#            nacmuj.1      escohom      escomuj     ocupahom     ocupamuj
# count  32010.000000  7989.000000  7989.000000  7989.000000  7989.000000
# mean     364.396657     7.209288     7.188885  8230.086244  8913.848667
# std      635.428709     3.103862     3.128046  2488.537261  2285.061499
# min       32.000000     1.000000     1.000000   110.000000  1120.000000
# 25%      320.000000     5.000000     5.000000  6111.000000  9711.000000
# 50%      320.000000     9.000000     9.000000  9712.000000  9712.000000
# 75%      320.000000     9.000000     9.000000  9999.000000  9999.000000
# max     9999.000000     9.000000     9.000000  9999.000000  9999.000000
#
# [8 rows x 32 columns]

# %%
for column in df.columns:
    print(f"{column}: {df[column].describe()}")
    print(f"Presenta entradas con NAN: {df[column].hasnans}")
    if df[column].hasnans:
        print(f"Cantidad de observaciones con NAN: {df[column].isna().sum()}")
    print("--------------------------------------------------------------------")
# Out:
# depreg: count    7989.000000
# mean        7.870447
# std         7.277590
# min         1.000000
# 25%         1.000000
# 50%         5.000000
# 75%        14.000000
# max        22.000000
# Name: depreg, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# depreg.1: count    32010.000000
# mean         7.476007
# std          7.048145
# min          1.000000
# 25%          1.000000
# 50%          5.000000
# 75%         13.000000
# max         22.000000
# Name: depreg.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# mupreg: count    7989.000000
# mean      791.729628
# std       728.342936
# min       101.000000
# 25%       101.000000
# 50%       511.000000
# 75%      1406.000000
# max      2217.000000
# Name: mupreg, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# mupreg.1: count    32010.000000
# mean       752.265355
# std        705.568406
# min        101.000000
# 25%        101.000000
# 50%        505.000000
# 75%       1301.000000
# max       2217.000000
# Name: mupreg.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# mesreg: count    7989.000000
# mean        6.653899
# std         3.373956
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        10.000000
# max        12.000000
# Name: mesreg, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# mesreg.1: count    32010.000000
# mean         6.507060
# std          3.375252
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%          9.000000
# max         12.000000
# Name: mesreg.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# añoreg: count    7989.000000
# mean     2010.772437
# std         0.647816
# min      2010.000000
# 25%      2010.000000
# 50%      2011.000000
# 75%      2011.000000
# max      2012.000000
# Name: añoreg, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# añoreg.1: count    32010.000000
# mean      2014.677882
# std          1.711261
# min       2012.000000
# 25%       2013.000000
# 50%       2015.000000
# 75%       2016.000000
# max       2018.000000
# Name: añoreg.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# diaocu: count    7989.000000
# mean       15.593441
# std         8.671648
# min         1.000000
# 25%         8.000000
# 50%        15.000000
# 75%        23.000000
# max        31.000000
# Name: diaocu, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# diaocu.1: count    32010.000000
# mean        15.741550
# std          8.691388
# min          1.000000
# 25%          8.000000
# 50%         16.000000
# 75%         23.000000
# max         31.000000
# Name: diaocu.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# mesocu: count    7989.000000
# mean        6.468770
# std         3.240978
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%         9.000000
# max        12.000000
# Name: mesocu, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# mesocu.1: count    32010.000000
# mean         6.255795
# std          3.242688
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          9.000000
# max         12.000000
# Name: mesocu.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# añoocu: count    7989.000000
# mean     2010.543748
# std         0.498114
# min      2010.000000
# 25%      2010.000000
# 50%      2011.000000
# 75%      2011.000000
# max      2011.000000
# Name: añoocu, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# añoocu.1: count    15736.000000
# mean      2015.912239
# std          0.795195
# min       2015.000000
# 25%       2015.000000
# 50%       2016.000000
# 75%       2017.000000
# max       2017.000000
# Name: añoocu.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 24263
# --------------------------------------------------------------------
# depocu: count    7989.000000
# mean        7.765177
# std         7.287616
# min         1.000000
# 25%         1.000000
# 50%         5.000000
# 75%        14.000000
# max        22.000000
# Name: depocu, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# depocu.1: count    32010.000000
# mean         7.540300
# std          7.026966
# min          1.000000
# 25%          1.000000
# 50%          5.000000
# 75%         13.000000
# max         22.000000
# Name: depocu.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# mupocu: count    7989.000000
# mean      779.573288
# std       728.785071
# min       101.000000
# 25%       101.000000
# 50%       502.000000
# 75%      1401.000000
# max      2217.000000
# Name: mupocu, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# mupocu.1: count    32010.000000
# mean       758.831740
# std        703.006587
# min        101.000000
# 25%        101.000000
# 50%        506.000000
# 75%       1301.000000
# max       2217.000000
# Name: mupocu.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# edadhom: count    7989.000000
# mean      741.666416
# std       426.310107
# min        15.000000
# 25%        54.000000
# 50%       999.000000
# 75%       999.000000
# max       999.000000
# Name: edadhom, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# edadhom.1: count    32010.000000
# mean       598.881412
# std        474.960170
# min         15.000000
# 25%         35.000000
# 50%        999.000000
# 75%        999.000000
# max        999.000000
# Name: edadhom.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# edadmuj: count    7989.000000
# mean      732.399925
# std       432.117090
# min        14.000000
# 25%        47.000000
# 50%       999.000000
# 75%       999.000000
# max       999.000000
# Name: edadmuj, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# edadmuj.1: count    32010.000000
# mean       595.179288
# std        477.040784
# min         15.000000
# 25%         32.000000
# 50%        999.000000
# 75%        999.000000
# max        999.000000
# Name: edadmuj.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# grethom: count    7989.000000
# mean        7.515334
# std         2.920439
# min         1.000000
# 25%         9.000000
# 50%         9.000000
# 75%         9.000000
# max         9.000000
# Name: grethom, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# gretmuj: count    7989.000000
# mean        7.550632
# std         2.890567
# min         1.000000
# 25%         9.000000
# 50%         9.000000
# 75%         9.000000
# max         9.000000
# Name: gretmuj, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# nachom: count    7988.000000
# mean      331.068102
# std       290.093652
# min        -1.000000
# 25%       320.000000
# 50%       320.000000
# 75%       320.000000
# max      9999.000000
# Name: nachom, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32011
# --------------------------------------------------------------------
# nachom.1: count    32010.000000
# mean       363.806092
# std        626.414776
# min         32.000000
# 25%        320.000000
# 50%        320.000000
# 75%        320.000000
# max       9999.000000
# Name: nachom.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# nacmuj: count    7988.000000
# mean      329.599399
# std       268.946944
# min        -1.000000
# 25%       320.000000
# 50%       320.000000
# 75%       320.000000
# max      9999.000000
# Name: nacmuj, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32011
# --------------------------------------------------------------------
# nacmuj.1: count    32010.000000
# mean       364.396657
# std        635.428709
# min         32.000000
# 25%        320.000000
# 50%        320.000000
# 75%        320.000000
# max       9999.000000
# Name: nacmuj.1, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 7989
# --------------------------------------------------------------------
# escohom: count    7989.000000
# mean        7.209288
# std         3.103862
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%         9.000000
# max         9.000000
# Name: escohom, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# escomuj: count    7989.000000
# mean        7.188885
# std         3.128046
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%         9.000000
# max         9.000000
# Name: escomuj, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# ocupahom: count    7989.000000
# mean     8230.086244
# std      2488.537261
# min       110.000000
# 25%      6111.000000
# 50%      9712.000000
# 75%      9999.000000
# max      9999.000000
# Name: ocupahom, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
# ocupamuj: count    7989.000000
# mean     8913.848667
# std      2285.061499
# min      1120.000000
# 25%      9711.000000
# 50%      9712.000000
# 75%      9999.000000
# max      9999.000000
# Name: ocupamuj, dtype: float64
# Presenta entradas con NAN: True
# Cantidad de observaciones con NAN: 32010
# --------------------------------------------------------------------
